# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
def tridiagonalnaya_matrix(A, b):
    n = len(A)
    P = np.zeros(n)
    Q = np.zeros(n)
    
    P[0] = -A[0, 1] / A[0, 0]
    Q[0] = b[0] / A[0, 0]
    for i in range(1, n):
        denominator = A[i, i] + A[i, i - 1] * P[i - 1]
        P[i] = -A[i, i] / denominator
        Q[i] = (b[i] - A[i, i - 1] * Q[i - 1]) / denominator
        
    x = np.zeros(n)
    x[n-1] = Q[n-1]

    for i in range(n-2, -1, -1):
        x[i] = P[i] * x[i+1] + Q[i]

    return x

A = np.array([
    [5, 3, 0, 0],
    [3, 6, 1, 0],
    [0, 1, 4, -2],
    [0, 0, 1, -3]])

b = np.array([8, 10, 3, -2])

x = tridiagonalnaya_matrix(A, b)
print(x)
# Out:
# [ 0.65853659  1.56910569 -0.23170732  0.58943089]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
def tridiagonalnaya_matrix(A, b):
    n = len(A)
    P = np.zeros(n)
    Q = np.zeros(n)
    
    P[0] = -A[0, 1] / A[0, 0]
    Q[0] = b[0] / A[0, 0]
    
    for i in range(1, n):
        denominator = A[i, i] + A[i, i - 1] * P[i - 1]
        P[i] = -A[i, i] / denominator
        Q[i] = (b[i] - A[i, i - 1] * Q[i - 1]) / denominator

    x = np.zeros(n)
    x[n-1] = Q[n-1]

    for i in range(n-2, -1, -1):
        x[i] = P[i] * x[i+1] + Q[i]

    return x

A = np.array([
    [1, 2, 0, 0],
    [2, -1, 1, 0],
    [0, 1, -1, 1],
    [0, 0, 1, 1]])

b = np.array([5, 3, 3, 7])

x = tridiagonalnaya_matrix(A, b)
print(x)
# Out:
# [-15.  10. -43.  50.]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
def tridiagonalnaya_matrix(A, b):
    n = len(A)
    P = np.zeros(n)
    Q = np.zeros(n)
    
    P[0] = -A[0, 1] / A[0, 0]
    Q[0] = b[0] / A[0, 0]
    
    for i in range(1, n):
        denominator = A[i, i] + A[i, i - 1] * P[i - 1]
        P[i] = -A[i, i] / denominator
        Q[i] = (b[i] - A[i, i - 1] * Q[i - 1]) / denominator

    x = np.zeros(n)
    x[n-1] = Q[n-1]

    for i in range(n-2, -1, -1):
        x[i] = P[i] * x[i+1] + Q[i]

    return x

A = np.array([
    [2, 1, 0, 0],
    [2, 3, -1, 0],
    [0, 1, -1, 3],
    [0, 0, 1, -1]])

b = np.array([4, 9, 12, -4])

x = tridiagonalnaya_matrix(A, b)
print(x)
# Out:
# [-2.14285714  8.28571429 -3.85714286  0.14285714]
